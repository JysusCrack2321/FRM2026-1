# %% [markdown]
# # Laboratorio 1
#
# Jesús Manuel Aragón Buitrago
#
# Juan Carlos González Ibarra
#
# Ángel Rivera Amórtegui
#
# Duvan Stiven Tique Osorio
#
#
# ## Punto 1: Movimiento en Línea Recta
# ![](img/motion_straight.png)
#
# ## Punto 2: Movimiento con Curva
# ![](img/motion_turn_radius.png)
# ![](img/motion_s_path.png)
# ## Punto 3: Girosensor
# ![](img/motion_sensor_gyro.png)
# ## Punto 4: Sensor Infrarrojo
# ![](img/sensor_ir.png)
# ## Punto 5: Sensor de Contacto
# ![](img/sensor_touch.png)
#
# ## 5. Código en bloques
#
# ## 6. Videos de ejecución
#
# ## 6. Videos de ejecución
#
# <video width="600" controls>
#   <source src="videos/Giro45Grados.mp4" type="video/mp4">
# </video>
#
# <video width="600" controls>
#   <source src="videos/Giro135Grados.mp4" type="video/mp4">
# </video>
#
# <video width="600" controls>
#   <source src="videos/GiroEnCirculos.mp4" type="video/mp4">
# </video>
#
# <video width="600" controls>
#   <source src="videos/MovimientoS.mp4" type="video/mp4">
# </video>
#
# <video width="600" controls>
#   <source src="videos/SensorContacto.mp4" type="video/mp4">
# </video>
#
# <video width="600" controls>
#   <source src="videos/SensorInfrarrojo.mp4" type="video/mp4">
# </video>
#
# <video width="600" controls>
#   <source src="videos/SensorUltrasonido.mp4" type="video/mp4">
# </video>
