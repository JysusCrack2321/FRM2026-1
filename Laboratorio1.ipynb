# %% [markdown]
# # Laboratorio 1
#
# Jesús Manuel Aragón Buitrago
#
# Juan Carlos González Ibarra
#
# Ángel Rivera Amórtegui
#
# Duvan Stiven Tique Osorio
#
#
# ## Punto 1: Movimiento en Línea Recta
# ![](img/motion_straight.png)
#
# ## Punto 2: Movimiento con Curva
# ![](img/motion_turn_radius.png)
# ![](img/motion_s_path.png)
# ## Punto 3: Girosensor
# ![](img/motion_sensor_gyro.png)
# ## Punto 4: Sensor Infrarrojo
# ![](img/sensor_ir.png)
# ## Punto 5: Sensor de Contacto
# ![](img/sensor_touch.png)
#
# ## 5. Código en bloques
#
# ## 6. Videos de ejecución
#
# ## 6. Videos de ejecución
#
# - [Giro 45°](videos/Giro45Grados.mp4)
# - [Giro 135°](videos/Giro135Grados.mp4)
# - [Giro en círculos](videos/GiroEnCirculos.mp4)
# - [Movimiento en S](videos/MovimientoS.mp4)
# - [Sensor de contacto](videos/SensorContacto.mp4)
# - [Sensor infrarrojo](videos/SensorInfrarrojo.mp4)
# - [Sensor ultrasonido](videos/SensorUltrasonido.mp4)
